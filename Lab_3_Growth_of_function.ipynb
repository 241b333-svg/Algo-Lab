# %% [markdown]
# <a href="https://colab.research.google.com/github/241b333-svg/Algo-Lab/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )
import matplotlib.pyplot as plt
def even_odd_count(numbers):
  even_count=0
  odd_count=0
  for num in numbers:
    if num%2==0:
      even_count+=1
    else:
      odd_count+=1
  return
  n_values=list(range(1,101))
  time_values=[]
  plt.figure()
  plt.plot(n_values,time_values)
  plt.xlabel("Input size n")
  plt.ylabel("Time")
  plt.title("O(1) Constant Time Complexity for Addition")
  plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#prob_3:take another example and write the code that runs in linear amount of time or has fixed number of steps of execution no matter what is the size of input..
#similar tp example-2 also plot the graph (eg. even_oddcounts elements greater than zero)
import matplotlib.pyplot as plt
def count_greater_than_zero(numbers):
    count = 0
    for values in numbers:
        if values > 0:
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    count_greater_than_zero(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity for count_greater_than_zero")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
# Binary Search function (logarithmic time)
import matplotlib.pyplot as plt
import math

def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    steps = 0
    while left <= right:
        steps += 1
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid, steps
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1, steps  # not found

# Generate data for plotting
sizes = [2**i for i in range(1, 11)]  # Input sizes increasing exponentially
steps_taken = []

for size in sizes:
    arr = list(range(size))  # Create a sorted list
    target = size - 1  # Target the last element for a worst-case scenario (or close to it)
    _, steps = binary_search(arr, target)
    steps_taken.append(steps)

# Plotting
plt.figure(figsize=(7,5))
plt.plot(sizes, steps_taken, marker='o', color='red', label='Steps taken')
plt.plot(sizes, [math.log2(n) for n in sizes], linestyle='--', color='blue', label='log base 2(n)') # Fixed string literal and added color
plt.xlabel("Input size n")
plt.ylabel("Steps")
plt.title("O(log n) Logarithmic Time Complexity")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
import matplotlib.pyplot as plt
import random
import time
import math

# Merge Sort implementation
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Measure runtime for different input sizes
sizes = [100, 500, 1000, 2000, 5000, 10000]
times = []

for n in sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]
    start = time.time()
    merge_sort(arr)
    end = time.time()
    times.append(end - start)

# Plotting
plt.figure(figsize=(7,5))
plt.plot(sizes, times, marker='o', color='red', label='Measured Time') # Corrected unterminated string literal
plt.plot(sizes, [n * math.log2(n) * 0.00001 for n in sizes], linestyle='--', color='blue', label='O(n log n)') # Added a scaled n log n comparison
plt.xlabel("Input size n")
plt.ylabel("Time (seconds)")
plt.title("O(n log n) Log-Linear Time Complexity (Merge Sort)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import matplotlib.pyplot as plt
import math

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import matplotlib.pyplot as plt
import random
import time
import math

# Merge Sort implementation
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Measure runtime for different input sizes
sizes = [100, 500, 1000, 2000, 5000, 10000]
times = []

for n in sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]
    start = time.time()
    merge_sort(arr)
    end = time.time()
    times.append(end - start)

# Plotting
plt.figure(figsize=(7,5))
plt.plot(sizes, times, marker='o', color='red', label='Measured Time')
plt.plot(sizes, [n*math.log2(n)/10000 for n in sizes], linestyle='--', color='blue', label='n log n reference (scaled)')
plt.title('Merge Sort Runtime vs Input Size')
plt.xlabel('Input Size (n)')
plt.ylabel('Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import matplotlib.pyplot as plt
import math

# Input sizes
sizes = [10, 50, 100, 500, 1000, 5000, 10000]

# Logarithmic growth (binary search steps ~ log2(n))
logarithmic = [math.log2(n) for n in sizes]

# Log-linear growth (merge sort steps ~ n log2(n))
log_linear = [n * math.log2(n) for n in sizes]

# Plotting
plt.figure(figsize=(8,6))
plt.plot(sizes, logarithmic, marker='o', color='green', label='Logarithmic O(log n)')
plt.plot(sizes, log_linear, marker='s', color='red', label='Log-Linear O(n log n)')
plt.title('Comparison of Logarithmic vs Log-Linear Growth')
plt.xlabel('Input Size (n)')
plt.ylabel('Steps (scaled)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)
