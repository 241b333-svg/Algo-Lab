# %% [markdown]
# <a href="https://colab.research.google.com/github/241b333-svg/Algo-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
# Code 1: Basic Dijkstra Implementation
graph = {
    'A': {'B': 1, 'C': 4},
    'B': {'A': 1, 'C': 2, 'D': 5},
    'C': {'A': 4, 'B': 2, 'D': 1},
    'D': {'B': 5, 'C': 1}
}

def dijkstra(graph, source):
    unvisited = list(graph.keys())
    distances = {node: float('inf') for node in graph}
    distances[source] = 0

    while unvisited:
        current = min(unvisited, key=lambda node: distances[node])
        unvisited.remove(current)

        for neighbor, weight in graph[current].items():
            if distances[current] + weight < distances[neighbor]:
                distances[neighbor] = distances[current] + weight

    return distances

print("Shortest distances:", dijkstra(graph, 'A'))
# Out:
# Shortest distances: {'A': 0, 'B': 1, 'C': 3, 'D': 4}

# %%
# Code 2: User Input Graph
def create_graph():
    graph = {}
    n = int(input("Enter number of nodes: "))
    for _ in range(n):
        node = input("Enter node name: ")
        edges = input(f"Enter neighbors of {node} in format (neighbor:weight, ...): ")
        graph[node] = {}
        for edge in edges.split(","):
            neighbor, weight = edge.split(":")
            graph[node][neighbor.strip()] = int(weight.strip())
    return graph

def dijkstra(graph, source):
    unvisited = list(graph.keys())
    distances = {node: float('inf') for node in graph}
    distances[source] = 0

    while unvisited:
        current = min(unvisited, key=lambda node: distances[node])
        unvisited.remove(current)

        for neighbor, weight in graph[current].items():
            if distances[current] + weight < distances[neighbor]:
                distances[neighbor] = distances[current] + weight

    return distances

graph = create_graph()
source = input("Enter source node: ")
print("Shortest distances:", dijkstra(graph, source))
# Out:
# Enter number of nodes: 4
# Enter node name: A
# Enter neighbors of A in format (neighbor:weight, ...): B:1
# Enter node name: B
# Enter neighbors of B in format (neighbor:weight, ...): C:4
# Enter node name: A
# Enter neighbors of A in format (neighbor:weight, ...): C:1
# Enter node name: C
# Enter neighbors of C in format (neighbor:weight, ...): B:2
# Enter source node: A
# Shortest distances: {'A': 0, 'B': 3, 'C': 1}

# %%
# Code 3: Dijkstra with Path Tracking
def dijkstra(graph, source):
    unvisited = list(graph.keys())
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    distances[source] = 0

    while unvisited:
        current = min(unvisited, key=lambda node: distances[node])
        unvisited.remove(current)

        for neighbor, weight in graph[current].items():
            if distances[current] + weight < distances[neighbor]:
                distances[neighbor] = distances[current] + weight
                previous[neighbor] = current

    return distances, previous

def shortest_path(previous, target):
    path = []
    while target:
        path.insert(0, target)
        target = previous[target]
    return path

graph = {
    'A': {'B': 1, 'C': 4},
    'B': {'A': 1, 'C': 2, 'D': 5},
    'C': {'A': 4, 'B': 2, 'D': 1},
    'D': {'B': 5, 'C': 1}
}

source = 'A'
distances, previous = dijkstra(graph, source)
for node in graph:
    print(f"Shortest path from {source} to {node}: {shortest_path(previous, node)} with distance {distances[node]}")
# Out:
# Shortest path from A to A: ['A'] with distance 0
# Shortest path from A to B: ['A', 'B'] with distance 1
# Shortest path from A to C: ['A', 'B', 'C'] with distance 3
# Shortest path from A to D: ['A', 'B', 'C', 'D'] with distance 4

# %%
# Code 4: Extended Graph with More Nodes
graph = {
    'A': {'B': 1, 'C': 4},
    'B': {'A': 1, 'C': 2, 'D': 5},
    'C': {'A': 4, 'B': 2, 'D': 1, 'E': 3},
    'D': {'B': 5, 'C': 1, 'F': 2},
    'E': {'C': 3, 'F': 4},
    'F': {'D': 2, 'E': 4}
}

def dijkstra(graph, source):
    unvisited = list(graph.keys())
    distances = {node: float('inf') for node in graph}
    previous = {node: None for node in graph}
    distances[source] = 0

    while unvisited:
        current = min(unvisited, key=lambda node: distances[node])
        unvisited.remove(current)

        for neighbor, weight in graph[current].items():
            if distances[current] + weight < distances[neighbor]:
                distances[neighbor] = distances[current] + weight
                previous[neighbor] = current

    return distances, previous

def shortest_path(previous, target):
    path = []
    while target:
        path.insert(0, target)
        target = previous[target]
    return path

for source in ['A', 'C', 'E']:
    print(f"\nSource: {source}")
    distances, previous = dijkstra(graph, source)
    for node in graph:
        print(f"Path to {node}: {shortest_path(previous, node)} with distance {distances[node]}")
# Out:
# Source: A
# Path to A: ['A'] with distance 0
# Path to B: ['A', 'B'] with distance 1
# Path to C: ['A', 'B', 'C'] with distance 3
# Path to D: ['A', 'B', 'C', 'D'] with distance 4
# Path to E: ['A', 'B', 'C', 'E'] with distance 6
# Path to F: ['A', 'B', 'C', 'D', 'F'] with distance 6
#
# Source: C
# Path to A: ['C', 'B', 'A'] with distance 3
# Path to B: ['C', 'B'] with distance 2
# Path to C: ['C'] with distance 0
# Path to D: ['C', 'D'] with distance 1
# Path to E: ['C', 'E'] with distance 3
# Path to F: ['C', 'D', 'F'] with distance 3
#
# Source: E
# Path to A: ['E', 'C', 'B', 'A'] with distance 6
# Path to B: ['E', 'C', 'B'] with distance 5
# Path to C: ['E', 'C'] with distance 3
# Path to D: ['E', 'C', 'D'] with distance 4
# Path to E: ['E'] with distance 0
# Path to F: ['E', 'F'] with distance 4
